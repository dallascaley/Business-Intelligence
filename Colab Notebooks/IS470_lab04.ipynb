# %% [markdown]
# #IS 470 Lab 4: Decision Tree vs Naive Bayes
#
# ---

# %% [markdown]
# This data set contains information of cars purchased at the Auction.
# <br>
# We will use this file to predict the quality of buying decisions and visualize decision processes.
# <br>
# <br>
# VARIABLE DESCRIPTIONS:<br>
# Auction: Auction provider at which the  vehicle was purchased<br>
# Color: Vehicle Color<br>
# IsBadBuy: Identifies if the kicked vehicle was an avoidable purchase<br>
# MMRCurrentAuctionAveragePrice: Acquisition price for this vehicle in average condition as of current day<br>
# Size: The size category of the vehicle (Compact, SUV, etc.)<br>
# TopThreeAmericanName:Identifies if the manufacturer is one of the top three American manufacturers<br>
# VehBCost: Acquisition cost paid for the vehicle at time of purchase<br>
# VehicleAge: The Years elapsed since the manufacturer's year<br>
# VehOdo: The vehicles odometer reading<br>
# WarrantyCost: Warranty price (term=36month  and millage=36K)<br>
# WheelType: The vehicle wheel type description (Alloy, Covers)<br>
# <br>
# Target variable: **IsBadBuy**

# %% [markdown]
# ###1. Upload and clean data

# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.naive_bayes import MultinomialNB

# %%
# Read data
car_kick = pd.read_csv("/content/drive/MyDrive/IS470_data/car_kick.csv")
car_kick
# Out:
#         PurchDate  VehYear  VehicleAge  VehOdo  \
# 0      1289952000     2006           4   51954
# 1      1242691200     2005           4   89127
# 2      1248220800     2006           3   71271
# 3      1285718400     2008           2   83338
# 4      1237334400     2007           2   58698
# ...           ...      ...         ...     ...
# 67206  1285804800     2008           2   56072
# 67207  1274918400     2004           6   94232
# 67208  1280448000     2004           6   79534
# 67209  1285200000     2003           7   79394
# 67210  1288742400     2004           6   94491
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# 0                                   6197                             7062
# 1                                   3688                             4783
# 2                                   6897                             8449
# 3                                   7878                             8925
# 4                                   8800                            10091
# ...                                  ...                              ...
# 67206                               6255                             6972
# 67207                               8359                             9645
# 67208                               2805                             3826
# 67209                               4042                             5296
# 67210                               5194                             6424
#
#        MMRAcquisitionRetailAveragePrice  MMRAcquisitonRetailCleanPrice  \
# 0                                  9605                          10426
# 1                                  4483                           5666
# 2                                  7949                           9625
# 3                                 11723                          13026
# 4                                 10004                          11398
# ...                                 ...                            ...
# 67206                              9852                          10567
# 67207                             12042                          13302
# 67208                              6132                           6871
# 67209                              7335                           8983
# 67210                              8532                           9941
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  ...  \
# 0                               5341                         6351  ...
# 1                               3688                         4783  ...
# 2                               6868                         8549  ...
# 3                               7801                         8704  ...
# 4                               7355                         8543  ...
# ...                              ...                          ...  ...
# 67206                           6326                         7126  ...
# 67207                           7505                         8188  ...
# 67208                           3106                         4479  ...
# 67209                           3534                         4732  ...
# 67210                           4417                         5807  ...
#
#        WheelTypeID  WheelType       Nationality          Size  \
# 0                2     Covers          AMERICAN        MEDIUM
# 1                2     Covers          AMERICAN        MEDIUM
# 2                1      Alloy          AMERICAN         LARGE
# 3                2     Covers          AMERICAN         LARGE
# 4                1      Alloy          AMERICAN         LARGE
# ...            ...        ...               ...           ...
# 67206            2     Covers          AMERICAN        MEDIUM
# 67207            1      Alloy  'TOP LINE ASIAN'  'MEDIUM SUV'
# 67208            1      Alloy          AMERICAN        MEDIUM
# 67209            2     Covers          AMERICAN  'MEDIUM SUV'
# 67210            1      Alloy     'OTHER ASIAN'        MEDIUM
#
#       TopThreeAmericanName  BYRNO VNZIP1 VNST IsOnlineSale IsBadBuy
# 0                 CHRYSLER  99750  32124   FL            0        0
# 1                     FORD  20833  78754   TX            0        0
# 2                       GM  22916  80011   CO            0        0
# 3                       GM  23657  94544   CA            0        0
# 4                       GM  20833  77086   TX            0        0
# ...                    ...    ...    ...  ...          ...      ...
# 67206             CHRYSLER  22808  77061   TX            0        1
# 67207                OTHER  17675  28273   NC            0        1
# 67208                   GM  18880  37771   TN            0        1
# 67209                   GM  23657  92337   CA            0        1
# 67210                OTHER    835  87105   NM            0        1
#
# [67211 rows x 31 columns]

# %%
car_kick.keys()
# Out:
# Index(['PurchDate', 'VehYear', 'VehicleAge', 'VehOdo',
#        'MMRAcquisitionAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice',
#        'MMRAcquisitionRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice',
#        'MMRCurrentAuctionAveragePrice', 'MMRCurrentAuctionCleanPrice',
#        'MMRCurrentRetailAveragePrice', 'MMRCurrentRetailCleanPrice',
#        'VehBCost', 'WarrantyCost', 'Auction', 'Make', 'Model', 'Trim',
#        'SubModel', 'Color', 'Transmission', 'WheelTypeID', 'WheelType',
#        'Nationality', 'Size', 'TopThreeAmericanName', 'BYRNO', 'VNZIP1',
#        'VNST', 'IsOnlineSale', 'IsBadBuy'],
#       dtype='object')

# %%
# Select the desired columns only
desired_columns = ['Auction', 'Color', 'IsBadBuy', 'MMRCurrentAuctionAveragePrice', 'Size','TopThreeAmericanName',
'VehBCost', 'VehicleAge', 'VehOdo', 'WarrantyCost', 'WheelType']
car_kick_desired = car_kick [desired_columns]

# %%
# Replacing 1 with Yes and 0 with No in the target column IsBadBuy
carAuction = car_kick_desired.copy() #why?
carAuction.loc[:, 'IsBadBuy'] = carAuction['IsBadBuy'].replace({0: 'No', 1: 'Yes'})
# Out:
# /tmp/ipython-input-1418416685.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['No' 'No' 'No' ... 'Yes' 'Yes' 'Yes']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   carAuction.loc[:, 'IsBadBuy'] = carAuction['IsBadBuy'].replace({0: 'No', 1: 'Yes'})

# %%
# Show the head rows of a data frame
carAuction.head()
# Out:
#    Auction   Color IsBadBuy  MMRCurrentAuctionAveragePrice    Size  \
# 0  MANHEIM  SILVER       No                           5341  MEDIUM
# 1    ADESA  SILVER       No                           3688  MEDIUM
# 2  MANHEIM     RED       No                           6868   LARGE
# 3  MANHEIM   BLACK       No                           7801   LARGE
# 4    ADESA   WHITE       No                           7355   LARGE
#
#   TopThreeAmericanName  VehBCost  VehicleAge  VehOdo  WarrantyCost WheelType
# 0             CHRYSLER      6500           4   51954          1086    Covers
# 1                 FORD      3680           4   89127           983    Covers
# 2                   GM      7170           3   71271          1974     Alloy
# 3                   GM      7670           2   83338          2152    Covers
# 4                   GM      7165           2   58698          1500     Alloy

# %%
# Examine missing values again
carAuction.isnull().sum()
# Out:
# Auction                          0
# Color                            0
# IsBadBuy                         0
# MMRCurrentAuctionAveragePrice    0
# Size                             0
# TopThreeAmericanName             0
# VehBCost                         0
# VehicleAge                       0
# VehOdo                           0
# WarrantyCost                     0
# WheelType                        0
# dtype: int64

# %%
# Examine variable type
carAuction.dtypes
# Out:
# Auction                          object
# Color                            object
# IsBadBuy                         object
# MMRCurrentAuctionAveragePrice     int64
# Size                             object
# TopThreeAmericanName             object
# VehBCost                          int64
# VehicleAge                        int64
# VehOdo                            int64
# WarrantyCost                      int64
# WheelType                        object
# dtype: object

# %%
# Change categorical variables to "category"
carAuction['Auction'] = carAuction['Auction'].astype('category')
carAuction['Color'] = carAuction['Color'].astype('category')
carAuction['IsBadBuy'] = carAuction['IsBadBuy'].astype('category')
carAuction['Size'] = carAuction['Size'].astype('category')
carAuction['TopThreeAmericanName'] = carAuction['TopThreeAmericanName'].astype('category')
carAuction['WheelType'] = carAuction['WheelType'].astype('category')

# %%
# Examine variable type
carAuction.dtypes
# Out:
# Auction                          category
# Color                            category
# IsBadBuy                         category
# MMRCurrentAuctionAveragePrice       int64
# Size                             category
# TopThreeAmericanName             category
# VehBCost                            int64
# VehicleAge                          int64
# VehOdo                              int64
# WarrantyCost                        int64
# WheelType                        category
# dtype: object

# %%
# Display all numeric variables
carAuction.select_dtypes(include=['number'])
# Out:
#        MMRCurrentAuctionAveragePrice  VehBCost  VehicleAge  VehOdo  \
# 0                               5341      6500           4   51954
# 1                               3688      3680           4   89127
# 2                               6868      7170           3   71271
# 3                               7801      7670           2   83338
# 4                               7355      7165           2   58698
# ...                              ...       ...         ...     ...
# 67206                           6326      6680           2   56072
# 67207                           7505      8265           6   94232
# 67208                           3106      4950           6   79534
# 67209                           3534      5220           7   79394
# 67210                           4417      5890           6   94491
#
#        WarrantyCost
# 0              1086
# 1               983
# 2              1974
# 3              2152
# 4              1500
# ...             ...
# 67206          1086
# 67207           909
# 67208          1506
# 67209          3967
# 67210          1774
#
# [67211 rows x 5 columns]

# %%
# Display all categorical variables
carAuction.select_dtypes(include=['category'])
# Out:
#        Auction   Color IsBadBuy          Size TopThreeAmericanName WheelType
# 0      MANHEIM  SILVER       No        MEDIUM             CHRYSLER    Covers
# 1        ADESA  SILVER       No        MEDIUM                 FORD    Covers
# 2      MANHEIM     RED       No         LARGE                   GM     Alloy
# 3      MANHEIM   BLACK       No         LARGE                   GM    Covers
# 4        ADESA   WHITE       No         LARGE                   GM     Alloy
# ...        ...     ...      ...           ...                  ...       ...
# 67206  MANHEIM     RED      Yes        MEDIUM             CHRYSLER    Covers
# 67207    ADESA   BLACK      Yes  'MEDIUM SUV'                OTHER     Alloy
# 67208    ADESA    GOLD      Yes        MEDIUM                   GM     Alloy
# 67209  MANHEIM   WHITE      Yes  'MEDIUM SUV'                   GM    Covers
# 67210  MANHEIM     RED      Yes        MEDIUM                OTHER     Alloy
#
# [67211 rows x 6 columns]

# %% [markdown]
# ###2. Partition the data set for Decision Tree model

# %%
# Create dummy variables (1 pts)
carAuction = pd.get_dummies(carAuction, columns=['Auction','Color','Size','TopThreeAmericanName','WheelType'], drop_first=True)
carAuction
# Out:
#       IsBadBuy  MMRCurrentAuctionAveragePrice  VehBCost  VehicleAge  VehOdo  \
# 0           No                           5341      6500           4   51954
# 1           No                           3688      3680           4   89127
# 2           No                           6868      7170           3   71271
# 3           No                           7801      7670           2   83338
# 4           No                           7355      7165           2   58698
# ...        ...                            ...       ...         ...     ...
# 67206      Yes                           6326      6680           2   56072
# 67207      Yes                           7505      8265           6   94232
# 67208      Yes                           3106      4950           6   79534
# 67209      Yes                           3534      5220           7   79394
# 67210      Yes                           4417      5890           6   94491
#
#        WarrantyCost  Auction_MANHEIM  Auction_OTHER  Color_BEIGE  Color_BLACK  \
# 0              1086             True          False        False        False
# 1               983            False          False        False        False
# 2              1974             True          False        False        False
# 3              2152             True          False        False         True
# 4              1500            False          False        False        False
# ...             ...              ...            ...          ...          ...
# 67206          1086             True          False        False        False
# 67207           909            False          False        False         True
# 67208          1506            False          False        False        False
# 67209          3967             True          False        False        False
# 67210          1774             True          False        False        False
#
#        ...  Size_LARGE  Size_MEDIUM  Size_SPECIALTY  Size_SPORTS  Size_VAN  \
# 0      ...       False         True           False        False     False
# 1      ...       False         True           False        False     False
# 2      ...        True        False           False        False     False
# 3      ...        True        False           False        False     False
# 4      ...        True        False           False        False     False
# ...    ...         ...          ...             ...          ...       ...
# 67206  ...       False         True           False        False     False
# 67207  ...       False        False           False        False     False
# 67208  ...       False         True           False        False     False
# 67209  ...       False        False           False        False     False
# 67210  ...       False         True           False        False     False
#
#        TopThreeAmericanName_FORD  TopThreeAmericanName_GM  \
# 0                          False                    False
# 1                           True                    False
# 2                          False                     True
# 3                          False                     True
# 4                          False                     True
# ...                          ...                      ...
# 67206                      False                    False
# 67207                      False                    False
# 67208                      False                     True
# 67209                      False                     True
# 67210                      False                    False
#
#        TopThreeAmericanName_OTHER  WheelType_Covers  WheelType_Special
# 0                           False              True              False
# 1                           False              True              False
# 2                           False             False              False
# 3                           False              True              False
# 4                           False             False              False
# ...                           ...               ...                ...
# 67206                       False              True              False
# 67207                        True             False              False
# 67208                       False             False              False
# 67209                       False              True              False
# 67210                        True             False              False
#
# [67211 rows x 39 columns]

# %%
carAuction.dtypes
# Out:
# IsBadBuy                         category
# MMRCurrentAuctionAveragePrice       int64
# VehBCost                            int64
# VehicleAge                          int64
# VehOdo                              int64
# WarrantyCost                        int64
# Auction_MANHEIM                      bool
# Auction_OTHER                        bool
# Color_BEIGE                          bool
# Color_BLACK                          bool
# Color_BLUE                           bool
# Color_BROWN                          bool
# Color_GOLD                           bool
# Color_GREEN                          bool
# Color_GREY                           bool
# Color_MAROON                         bool
# Color_ORANGE                         bool
# Color_OTHER                          bool
# Color_PURPLE                         bool
# Color_RED                            bool
# Color_SILVER                         bool
# Color_WHITE                          bool
# Color_YELLOW                         bool
# Size_'LARGE TRUCK'                   bool
# Size_'MEDIUM SUV'                    bool
# Size_'SMALL SUV'                     bool
# Size_'SMALL TRUCK'                   bool
# Size_COMPACT                         bool
# Size_CROSSOVER                       bool
# Size_LARGE                           bool
# Size_MEDIUM                          bool
# Size_SPECIALTY                       bool
# Size_SPORTS                          bool
# Size_VAN                             bool
# TopThreeAmericanName_FORD            bool
# TopThreeAmericanName_GM              bool
# TopThreeAmericanName_OTHER           bool
# WheelType_Covers                     bool
# WheelType_Special                    bool
# dtype: object

# %%
# Examine the porportion of target variable for data set  (note, had to change variable name because of dummys)
target = carAuction['IsBadBuy']
print(target.value_counts(normalize=True))
# Out:
# IsBadBuy
# No     0.904539
# Yes    0.095461
# Name: proportion, dtype: float64

# %%
# Partition the data
predictors = carAuction.drop(['IsBadBuy'],axis=1)
predictors_train, predictors_test, target_train, target_test = train_test_split(predictors, target, test_size=0.3, random_state=0)
print(predictors_train.shape, predictors_test.shape, target_train.shape, target_test.shape)
# Out:
# (47047, 38) (20164, 38) (47047,) (20164,)

# %%
# Taking steps to balance the train data
# Combine predictors_train and target_train into a single DataFrame
combined_train_df = pd.concat([predictors_train, target_train], axis=1)

# Separate majority and minority classes
majority_df = combined_train_df[combined_train_df['IsBadBuy'] == 'No']
minority_df = combined_train_df[combined_train_df['IsBadBuy'] == 'Yes']

# Undersample the majority class randomly
undersampled_majority = majority_df.sample(n=len(minority_df), random_state=5)

# Combine the undersampled majority class and the minority class
undersampled_data = pd.concat([undersampled_majority, minority_df])

# Shuffle the combined DataFrame to ensure randomness
balanced_data = undersampled_data.sample(frac=1, random_state=5)

# Split the balanced_data into predictors_train and target_train
predictors_train = balanced_data.drop(columns=['IsBadBuy'])
target_train = balanced_data['IsBadBuy']

# %%
# Examine the porportion of target variable for train set
print(target_train.value_counts(normalize=True), target_train.shape)
# Out:
# IsBadBuy
# No     0.5
# Yes    0.5
# Name: proportion, dtype: float64 (8838,)

# %%
# Examine the porportion of target variable for testing data set
print(target_test.value_counts(normalize=True))
# Out:
# IsBadBuy
# No     0.900962
# Yes    0.099038
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Decision Tree model prediction

# %%
# Build a decision tree model on training data with max_depth = 3
model_DT = DecisionTreeClassifier(criterion = "entropy", random_state = 1, max_depth = 3)
model_DT.fit(predictors_train, target_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=1)

# %%
# Plot the tree (0.5 pts)
fig = plt.figure(figsize=(30,20))
tree.plot_tree(model_DT,
               feature_names=list(predictors_train.columns),
               class_names=['No','Yes'],
               filled=True)
# Out:
# [Text(0.5, 0.875, 'VehicleAge <= 4.5\nentropy = 1.0\nsamples = 8838\nvalue = [4419, 4419]\nclass = No'),
#  Text(0.25, 0.625, 'VehicleAge <= 2.5\nentropy = 0.958\nsamples = 4577\nvalue = [2840.0, 1737.0]\nclass = No'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'VehBCost <= 6377.5\nentropy = 0.81\nsamples = 1060\nvalue = [796.0, 264.0]\nclass = No'),
#  Text(0.0625, 0.125, 'entropy = 0.974\nsamples = 170\nvalue = [101, 69]\nclass = No'),
#  Text(0.1875, 0.125, 'entropy = 0.759\nsamples = 890\nvalue = [695, 195]\nclass = No'),
#  Text(0.375, 0.375, 'VehBCost <= 4652.5\nentropy = 0.981\nsamples = 3517\nvalue = [2044.0, 1473.0]\nclass = No'),
#  Text(0.3125, 0.125, 'entropy = 0.969\nsamples = 272\nvalue = [108, 164]\nclass = Yes'),
#  Text(0.4375, 0.125, 'entropy = 0.973\nsamples = 3245\nvalue = [1936, 1309]\nclass = No'),
#  Text(0.75, 0.625, 'VehBCost <= 4782.5\nentropy = 0.951\nsamples = 4261\nvalue = [1579, 2682]\nclass = Yes'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'WarrantyCost <= 1618.0\nentropy = 0.869\nsamples = 1411\nvalue = [410, 1001]\nclass = Yes'),
#  Text(0.5625, 0.125, 'entropy = 0.911\nsamples = 886\nvalue = [289, 597]\nclass = Yes'),
#  Text(0.6875, 0.125, 'entropy = 0.779\nsamples = 525\nvalue = [121, 404]\nclass = Yes'),
#  Text(0.875, 0.375, 'VehOdo <= 56296.5\nentropy = 0.977\nsamples = 2850\nvalue = [1169, 1681]\nclass = Yes'),
#  Text(0.8125, 0.125, 'entropy = 0.983\nsamples = 236\nvalue = [136, 100]\nclass = No'),
#  Text(0.9375, 0.125, 'entropy = 0.968\nsamples = 2614\nvalue = [1033, 1581]\nclass = Yes')]

# %%
# Text version of decision tree
print(tree.export_text(model_DT, feature_names=list(carAuction.columns)[1:]))
# Out:
# |--- VehicleAge <= 4.50
# |   |--- VehicleAge <= 2.50
# |   |   |--- VehBCost <= 6377.50
# |   |   |   |--- class: No
# |   |   |--- VehBCost >  6377.50
# |   |   |   |--- class: No
# |   |--- VehicleAge >  2.50
# |   |   |--- VehBCost <= 4652.50
# |   |   |   |--- class: Yes
# |   |   |--- VehBCost >  4652.50
# |   |   |   |--- class: No
# |--- VehicleAge >  4.50
# |   |--- VehBCost <= 4782.50
# |   |   |--- WarrantyCost <= 1618.00
# |   |   |   |--- class: Yes
# |   |   |--- WarrantyCost >  1618.00
# |   |   |   |--- class: Yes
# |   |--- VehBCost >  4782.50
# |   |   |--- VehOdo <= 56296.50
# |   |   |   |--- class: No
# |   |   |--- VehOdo >  56296.50
# |   |   |   |--- class: Yes

# %%
# Make predictions on testing data
prediction_on_test_DT = model_DT.predict(predictors_test)

# %%
# Examine the evaluation results on testing data: confusion_matrix
cm_DT = confusion_matrix(target_test, prediction_on_test_DT)
ConfusionMatrixDisplay(confusion_matrix=cm_DT, display_labels=model_DT.classes_).plot()

# %%
# Examine the evaluation results on testing data: accuracy, precision, recall, and f1-score
print(classification_report(target_test, prediction_on_test_DT))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.94      0.63      0.75     18167
#          Yes       0.15      0.61      0.24      1997
#
#     accuracy                           0.63     20164
#    macro avg       0.54      0.62      0.50     20164
# weighted avg       0.86      0.63      0.70     20164

# %% [markdown]
# ## 3. Naive Bayes model prediction

# %%
# Build a Naive Bayes model on training data with default setting (1 point)
model_NB = MultinomialNB()
model_NB.fit(predictors_train, target_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on testing data (0.5 points)
prediction_on_test_NB = model_NB.predict(predictors_test)

# %%
# Examine the evaluation results on testing data: confusion_matrix (0.5 points)
cm_NB = confusion_matrix(target_test, prediction_on_test_NB)
ConfusionMatrixDisplay(confusion_matrix=cm_NB, display_labels=model_NB.classes_).plot()
#plot_confusion_matrix(model, predictors_test, target_test, cmap=plt.cm.Blues, values_format='d')

# %%
# Examine the evaluation results on testing data: accuracy, precision, recall, and f1-score (1 point)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(target_test, prediction_on_test_NB)
precision = precision_score(target_test, prediction_on_test_NB, pos_label='Yes')
recall = recall_score(target_test, prediction_on_test_NB, pos_label='Yes')
f1 = f1_score(target_test, prediction_on_test_NB, pos_label='Yes')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.5998
# Precision: 0.1401
# Recall: 0.5919
# F1-score: 0.2266

# %% [markdown]
# Note: all questions below refer to Nieve Baise model

# %% [markdown]
# Q1. On the testing set, how many bad buy cars are predicted as Not bad buy? (1 point)<br>  815

# %% [markdown]
# Q2. On the testing set, how many cars are predicted as Not bad buy? (1 point)<br>  815 + 10913 = 11728

# %% [markdown]
# Q3. On the testing set, how many bad buy cars are identified correctly by the naive bayes model in testing data? (1 points)<br> 1182

# %% [markdown]
# Q4. On the testing set, if the naive bayes predicts a car as bad buy, what is the probability that such prediction is correct? (1 points)<br> 1182 / (1182 + 7254) = 0.1401

# %% [markdown]
# Q5. Does the naive bayes model have better performance on majority (IsBadBuy = 'No') or minority class (IsBadBuy = 'Yes')? why?  (1 point)<br>  we just did the minority class, so the math for the majority class is this: 815 / (815 + 10913) = 0.0695  Since this number is more than the minority, I would say it has better performance on the majority

# %% [markdown]
# Q6. Compared to the naive bayes model, which model can better identify Bad Buy cars? why?  (1 points)<br>  What we haven't done is figured out the performance of the Decision tree model for the minority class. lets do that here.  This would be 1214 / (783 + 1214) = 0.6079  Since 0.6079 is larger than 0.1401 then i would say that the Decision tree model has better performance

# %%
# !jupyter nbconvert "/content/drive/MyDrive/Colab Notebooks/IS470_lab04.ipynb" --to html --output "/content/drive/MyDrive/Output/IS470_Lab04.html"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/IS470_lab04.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 3 image(s).
# [NbConvertApp] Writing 874996 bytes to /content/drive/MyDrive/Output/IS470_Lab04.html
